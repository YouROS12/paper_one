# %%
import random
import time
print("Cell 1: Module imports and setup complete.")
# Out:
# Cell 1: Module imports and setup complete.

# %%
# Cell 2: Perform some calculations
data = [random.randint(1, 100) for _ in range(10)]
print(f"Generated data: {data}")
mean_val = sum(data) / len(data)
print(f"Mean value: {mean_val}")
# Out:
# Generated data: [55, 76, 5, 21, 24, 76, 45, 37, 38, 93]
# Mean value: 47.0

# %%
# Cell 3: Final Output
print("Cell 3: Execution finished.")
time.sleep(1)
print("Goodbye!")
# Out:
# Cell 3: Execution finished.
# Goodbye!
